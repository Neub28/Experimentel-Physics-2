# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import scipy.stats as stats
import scipy.io as io

plt.rc("font", family=["Helvetica", "Arial"]) #skifter skrifttype
plt.rc("axes", labelsize=18)   #skriftstørrelse af `xlabel` og `ylabel`
plt.rc("xtick", labelsize=16, direction="out")  #skriftstørrelse af ticks og viser ticks øverst
plt.rc("ytick", labelsize=16, direction="out")
plt.rc("axes", titlesize=22)
plt.rc("legend", fontsize=16)

# %%
path_array = [r"C:/Users/nicol/Experimentel Physics/Experimentel-Physics-2/Michelson-interferometer", 
              r"/Users/karsten/eksperimental/Experimentel-Physics-2/Michelson-interferometer"]

data = io.loadmat(path_array[0] + r"/DataDay1.mat")
dA = data.get("A")
dB_old = data.get("B")
dB = np.transpose(dB_old)[0]

#print(type(data))

#for key in data :
 #   print(key)

# %%
plt.plot(range(len(dA)), dA, 'o', markersize=5)

# %%
plt.plot(range(len(dB)), dB, 'o', markersize=5)

# %%
plt.plot(dB, dA, 'o')

# %%
dB_list = []
i_list = []

for i in range(len(dB)) : 
    if(i+1 == len(dB)) : 
        break
    if(i == 0) : 
        dB_list.append(dB[i])
    
    if dB[i+1] != dB[i] : 
        boolsk = True
        array = [3, 2, 1]
        for tr in array: 
            if len(dB_list) >= tr : 
                if dB_list[-(tr)] == dB[i] :
                    boolsk = False
        if boolsk == True : 
            i_list.append(i)
            dB_list.append(dB[i])

# %%
print(len(dB_list))
print(len(dB))
print(len(i_list))
#print(i_list)
print(dB_list[0:100])
# Out:
# 503
# 961539
# 502
# [7.140133, 7.3142223, 7.4889274, 7.663017, 7.837106, 8.011196, 8.185286, 8.359375, 8.533464, 8.707554, 8.881643, 9.056349, 9.230438, 9.404528, 9.578617, 9.752707, 9.926796, 10.100885, 9.578617, 9.752707, 9.404528, 9.230438, 9.056349, 8.881643, 8.707554, 8.533464, 8.359375, 8.185286, 8.011196, 7.837106, 7.663017, 7.4889274, 7.3142223, 7.140133, 6.9660435, 6.7919536, 6.617864, 6.4437747, 6.269685, 6.0955954, 5.920891, 5.7468014, 5.5727115, 5.398622, 5.2245326, 5.0504427, 4.8763533, 4.702264, 4.5281744, 4.3534694, 4.17938, 4.0052905, 3.8312008, 3.6571112, 3.4830217, 3.308932, 3.1348424, 2.9601378, 2.7860482, 2.6119587, 2.437869, 2.2637794, 2.08969, 1.9156004, 1.7415109, 1.5674212, 1.3927165, 1.218627, 1.0445374, 0.8704478, 0.69635826, 1.218627, 1.0445374, 1.3927165, 1.5674212, 1.7415109, 1.9156004, 2.08969, 2.2637794, 2.437869, 2.6119587, 2.7860482, 2.9601378, 3.1348424, 3.308932, 3.4830217, 3.6571112, 3.8312008, 4.0052905, 4.17938, 4.3534694, 4.5281744, 4.702264, 4.8763533, 5.0504427, 5.2245326, 5.398622, 5.5727115, 5.7468014, 5.920891]

# %%
plt.plot(range(len(dB_list)), dB_list)

# %%
grad = np.gradient(dB_list)

# %%
plt.plot(i_list, dB_list[:-1])
plt.plot(range(len(dB)), dB)

# %%
array = [4, 3, 2, 1]
for tr in array : 
    print(tr)
# Out:
# 4
# 3
# 2
# 1

# %%
plt.plot(range(len(grad)), grad, 'o')
print(len(grad))
# Out:
# 493
